# %% [markdown]
# # **HW 2: Optimize and train Deep Models**
#
# In this homework, we will explore how to develop a simple Deep Neural Network for image classification. We will explore two common libraries: TensorFlow and Keras.
# Then we will explore how to face a well know problem that is common to encounter during the training phase: the Overfitting.
# Finally, we will study how to perform a fair model selection.
# Hint: Before starting the exercise take a look at how Tensorflow and Keras are designed.

# %% [markdown]
# ## Exercise 2.1: Image Classficiation with Tensorflow and Keras
#
# In this first exercise we will develop a 3 layer Neural Network to perfrom image classification.
#
# Let's start importing the libraries we will need and setting a couple of environmental variables.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn
import sys
import tensorflow as tf
from tensorflow import keras  # tf.keras
import time

#Set the log level in order to hide the unuseful warnings
import logging
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" 

tf.random.set_seed(42)

# %% [markdown]
# ### Load Data: Fashion MNIST dataset
#
# We will use the Fashion MNIST dataset, a dataset of Zalando's articles. Each sample is a 28x28 pixels grayscale image, associated with a label from 10 classes:
#
# class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
#
# Each pixel intensity is represented by a uint8 (byte) from 0 to 255.
# We will divide the dataset in training, testing and validation set. As you already know, the training set will be used to train the model, the validation set will be used to perform model selection and finally, the test set will be used to asses the performance of deep network.

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = (
    fashion_mnist.load_data()) #The dataset is already divede in test and training...

#We extract the first 5000 samples of the training set, to use them as the validation set
X_valid, X_train = X_train_full[:5000], X_train_full[5000:] 
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# Let's take a look at a sample of the images in the dataset:

# %%
n_rows = 5
n_cols = 10
plt.figure(figsize=(n_cols*1.4, n_rows * 1.6))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(class_names[y_train[index]])
plt.show()

# %% [markdown]
# ### Define the model:
#
# Let's build a Sequential model (keras.models.Sequential) and add four layers to it by calling its add() method:
#
#
# *  we start with a Flatten layer (keras.layers.Flatten) to convert each 28x28 image to a single row of 784 pixel values. Since it is the first layer in your model, you should specify the input_shape argument, leaving out the batch size: [28, 28];
# *  a Dense layer (keras.layers.Dense) with 300 neurons, and the "relu" activation function;
# * another Dense layer with 100 neurons, also with the "relu" activation function;
# * a final Dense layer with 10 output neurons (one per class), and with the "softmax" activation function to ensure that the sum of all the estimated class probabilities for each image is equal to 1.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

# %% [markdown]
# Call the model's summary() method to check if the model has been built correctly. Also, try using keras.utils.plot_model() to save an image of your model's architecture.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 300)               235500
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "my_mnist_model.png", show_shapes=True)

# %% [markdown]
# As you can see, the first dimension of each layer is not defined (?), indeed this dimension in each layer is variable and depends on the batch size.

# %% [markdown]
# ### Optimize the model:
#
# After the model has been created, you must call its compile() method to specify the loss function and the optimizer to use.
#
# The conventional way is to have the target outputs to match the output shape. In this case that would mean to convert the targets to the one-hot encoded array to match with the output shape.
# However, with the help of the sparse_categorical_crossentropy loss function, we can skip that step and keep the integers as targets.
#
#  In this case, we want to use the "sparse_categorical_crossentropy" loss, and the SGD optimizer (stochastic gradient descent).
#
#
#
# Moreover, you can optionally specify a list of additional metrics that should be measured during training. In this case we specify metrics=["accuracy"].

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-3),
              metrics=["accuracy"])

# %% [markdown]
# Now our model is ready to be trained. Call its fit() method, passing to it the input features (X_train) and the target classes (y_train). Set the number of epoch to 20.
# In order to validate our model we will also pass the validation data by setting validation_data=(X_valid, y_valid). Keras will compute the loss and the additional metrics (the accuracy in this case) on the validation set at the end of each epoch. If the loss on the training set is much lower than the one on the validation set, your model is probably overfitting the training set. Note: the fit() method will return a History object containing training stats.

# %%
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 6s 3ms/step - loss: 11.2452 - accuracy: 0.6505 - val_loss: 0.6746 - val_accuracy: 0.7664
# Epoch 2/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5806 - accuracy: 0.7910 - val_loss: 0.5250 - val_accuracy: 0.8206
# Epoch 3/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4961 - accuracy: 0.8164 - val_loss: 0.5444 - val_accuracy: 0.8116
# Epoch 4/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4553 - accuracy: 0.8297 - val_loss: 0.4841 - val_accuracy: 0.8244
# Epoch 5/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4411 - accuracy: 0.8362 - val_loss: 0.4528 - val_accuracy: 0.8422
# Epoch 6/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4129 - accuracy: 0.8477 - val_loss: 0.4652 - val_accuracy: 0.8450
# Epoch 7/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3982 - accuracy: 0.8544 - val_loss: 0.4533 - val_accuracy: 0.8470
# Epoch 8/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3824 - accuracy: 0.8581 - val_loss: 0.4786 - val_accuracy: 0.8364
# Epoch 9/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3799 - accuracy: 0.8588 - val_loss: 0.4349 - val_accuracy: 0.8504
# Epoch 10/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3635 - accuracy: 0.8664 - val_loss: 0.4306 - val_accuracy: 0.8558
# Epoch 11/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3529 - accuracy: 0.8662 - val_loss: 0.4207 - val_accuracy: 0.8606
# Epoch 12/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3489 - accuracy: 0.8693 - val_loss: 0.4236 - val_accuracy: 0.8580
# Epoch 13/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3403 - accuracy: 0.8726 - val_loss: 0.4288 - val_accuracy: 0.8574
# Epoch 14/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3360 - accuracy: 0.8741 - val_loss: 0.4361 - val_accuracy: 0.8548
# Epoch 15/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3297 - accuracy: 0.8751 - val_loss: 0.4157 - val_accuracy: 0.8640
# Epoch 16/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3230 - accuracy: 0.8786 - val_loss: 0.4252 - val_accuracy: 0.8628
# Epoch 17/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3183 - accuracy: 0.8802 - val_loss: 0.4357 - val_accuracy: 0.8562
# Epoch 18/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3155 - accuracy: 0.8804 - val_loss: 0.4290 - val_accuracy: 0.8652
# Epoch 19/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3084 - accuracy: 0.8844 - val_loss: 0.4140 - val_accuracy: 0.8688
# Epoch 20/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3084 - accuracy: 0.8854 - val_loss: 0.4263 - val_accuracy: 0.8594

# %% [markdown]
# Let's plot the loss and the accuracy trends on both training and validation sets. We define the "plot_learning_curves" because we will reuse it in the next steps.

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()
plot_learning_curves(history)

# %% [markdown]
# ### Evaluate the model:
#
# Now, our model has been optimized on the training set, and as you can see the performance on the validation set in quite similar (so it does not overfit the training data). Let's now evaluate the performance of our model using the test set.

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.4750 - accuracy: 0.8357
# [0.47502079606056213, 0.8356999754905701]

# %% [markdown]
# ### Input normalization:
#
# When using Gradient Descent, it is usually a good idea to ensure that all the features have a similar scale. It's a common practice to scale your data inputs to have zero mean and unit variance. This is known as the standard scaler approach.
# Try to standardize the pixel values and see if this improves the performance of your neural network.

# %%
#To complete: define X_train_scaled, X_valid_scaled and X_test_scaled, the sets 
#that contain the normalized inputs.
#Hint: For each feature (pixel intensity), you must subtract the mean() of that 
#feature (across all instances, so use axis=0) and divide by its standard 
#deviation (std(), again axis=0)

X_train_scaled = (X_train-X_train.mean(axis=0) )/X_train.std(axis=0)
X_valid_scaled = (X_valid-X_train.mean(axis=0) )/X_train.std(axis=0)
X_test_scaled =  (X_test-X_train.mean(axis=0) )/X_train.std(axis=0)

#Make sure you compute the means and standard deviations on the training set,
#and use these statistics to scale the training set, the validation set and the
# test set

#Alternatively, you can use Scikit-Learn's StandardScaler...

# %% [markdown]
# Let's define the model in order to re-initialize the weights and then train it by using the normalize data.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-3),
              metrics=["accuracy"])

history = model.fit(X_train_scaled, y_train, epochs=20,
                    validation_data=(X_valid_scaled, y_valid))
print("Model Evaluation")
model.evaluate(X_test_scaled, y_test)
plot_learning_curves(history)
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 6s 3ms/step - loss: 1.3077 - accuracy: 0.5730 - val_loss: 0.6307 - val_accuracy: 0.7850
# Epoch 2/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6095 - accuracy: 0.7908 - val_loss: 0.5275 - val_accuracy: 0.8114
# Epoch 3/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5223 - accuracy: 0.8175 - val_loss: 0.4838 - val_accuracy: 0.8300
# Epoch 4/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4759 - accuracy: 0.8320 - val_loss: 0.4545 - val_accuracy: 0.8412
# Epoch 5/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4571 - accuracy: 0.8406 - val_loss: 0.4367 - val_accuracy: 0.8470
# Epoch 6/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4270 - accuracy: 0.8489 - val_loss: 0.4231 - val_accuracy: 0.8520
# Epoch 7/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4119 - accuracy: 0.8561 - val_loss: 0.4114 - val_accuracy: 0.8552
# Epoch 8/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3943 - accuracy: 0.8614 - val_loss: 0.4039 - val_accuracy: 0.8596
# Epoch 9/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3930 - accuracy: 0.8627 - val_loss: 0.3950 - val_accuracy: 0.8622
# Epoch 10/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3747 - accuracy: 0.8673 - val_loss: 0.3896 - val_accuracy: 0.8618
# Epoch 11/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3684 - accuracy: 0.8710 - val_loss: 0.3835 - val_accuracy: 0.8656
# Epoch 12/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3584 - accuracy: 0.8739 - val_loss: 0.3788 - val_accuracy: 0.8660
# Epoch 13/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3516 - accuracy: 0.8767 - val_loss: 0.3733 - val_accuracy: 0.8690
# Epoch 14/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3475 - accuracy: 0.8771 - val_loss: 0.3704 - val_accuracy: 0.8688
# Epoch 15/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3443 - accuracy: 0.8791 - val_loss: 0.3672 - val_accuracy: 0.8690
# Epoch 16/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3349 - accuracy: 0.8819 - val_loss: 0.3626 - val_accuracy: 0.8724
# Epoch 17/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3281 - accuracy: 0.8844 - val_loss: 0.3603 - val_accuracy: 0.8722
# Epoch 18/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3272 - accuracy: 0.8838 - val_loss: 0.3566 - val_accuracy: 0.8732
# Epoch 19/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3242 - accuracy: 0.8860 - val_loss: 0.3557 - val_accuracy: 0.8754
# Epoch 20/20
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3224 - accuracy: 0.8866 - val_loss: 0.3518 - val_accuracy: 0.8762
# Model Evaluation
# 313/313 [==============================] - 0s 2ms/step - loss: 0.3812 - accuracy: 0.8636

# %% [markdown]
# Note that the validation curve is smoother than in the previous test and it is also more simlar to the training curve.

# %% [markdown]
# ## Exercise 2.2: Overfiting
#
# A common problem that occurs when you train a deep neural network is overfittig. Overfitting occurs when you achieve a good fit of your model on the training data, while it does not generalize well on new, unseen data. In other words, the model learned patterns specific to the training data, which are irrelevant in other data.
# As we have seen in the previous exercise, our model does not overfit the training data. In this exercise, we try to modify the training parameters in order to have a model that overfits.
# Overfitting can have many causes and usually is a combination of some of them, for instance: too many parameters/ layers, too few training samples, wrong learning rate (usualy too high), etc..

# %%
#To complete: modify the previuos model in order to obtain  a new mdel that overfit the training data
#HINT: A model tends to overfit when too few training examples are available
X_train_small = X_train[:500]
y_train_small = y_train[:500]

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))

#To complete: Add layers
#HINT: A model tends to overfit  when the number of learnable parameters is very high compared to the number of training samples
#HINT: Is it possible to use different activation functions than ReLu


model.add(keras.layers.Dense(500, activation=tf.nn.leaky_relu)) 
model.add(keras.layers.Dense(400, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-3)) #To complete:learning rate

#HINT: A model tends to overfit when the number of training epochs is high
history = model.fit(X_train_small, y_train_small, epochs=50, #To complete: number of epochs
                    validation_data=(X_valid, y_valid))
print("Model Evaluation")
model.evaluate(X_test, y_test)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 39ms/step - loss: 385.3941 - val_loss: 205.4538
# Epoch 2/50
# 16/16 [==============================] - 0s 29ms/step - loss: 86.4814 - val_loss: 2.1123
# Epoch 3/50
# 16/16 [==============================] - 0s 29ms/step - loss: 1.5448 - val_loss: 1.8070
# Epoch 4/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.8288 - val_loss: 1.7430
# Epoch 5/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.7642 - val_loss: 1.5233
# Epoch 6/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.5940 - val_loss: 1.6561
# Epoch 7/50
# 16/16 [==============================] - 0s 28ms/step - loss: 0.5516 - val_loss: 1.5324
# Epoch 8/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.4653 - val_loss: 1.5758
# Epoch 9/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.4432 - val_loss: 1.5765
# Epoch 10/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.4365 - val_loss: 1.5370
# Epoch 11/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.3448 - val_loss: 1.6663
# Epoch 12/50
# 16/16 [==============================] - 0s 28ms/step - loss: 0.4327 - val_loss: 1.6328
# Epoch 13/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.3539 - val_loss: 1.5650
# Epoch 14/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2959 - val_loss: 1.6615
# Epoch 15/50
# 16/16 [==============================] - 0s 32ms/step - loss: 0.3282 - val_loss: 1.5603
# Epoch 16/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2835 - val_loss: 1.6369
# Epoch 17/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2577 - val_loss: 1.6205
# Epoch 18/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2516 - val_loss: 1.5711
# Epoch 19/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2763 - val_loss: 1.5979
# Epoch 20/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2312 - val_loss: 1.6376
# Epoch 21/50
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2160 - val_loss: 1.6046
# Epoch 22/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2107 - val_loss: 1.6351
# Epoch 23/50
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2066 - val_loss: 1.6463
# Epoch 24/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1509 - val_loss: 1.7631
# Epoch 25/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1840 - val_loss: 1.6354
# Epoch 26/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1559 - val_loss: 1.6789
# Epoch 27/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1692 - val_loss: 1.7218
# Epoch 28/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1476 - val_loss: 1.7247
# Epoch 29/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1755 - val_loss: 1.6357
# Epoch 30/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1372 - val_loss: 1.7171
# Epoch 31/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1646 - val_loss: 1.6797
# Epoch 32/50
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1184 - val_loss: 1.6945
# Epoch 33/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1223 - val_loss: 1.6670
# Epoch 34/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1136 - val_loss: 1.6778
# Epoch 35/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1261 - val_loss: 1.7208
# Epoch 36/50
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0778 - val_loss: 1.7463
# Epoch 37/50
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0885 - val_loss: 1.7394
# Epoch 38/50
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0755 - val_loss: 1.7712
# Epoch 39/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0812 - val_loss: 1.8376
# Epoch 40/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0921 - val_loss: 1.8087
# Epoch 41/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0736 - val_loss: 1.8265
# Epoch 42/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0732 - val_loss: 1.7809
# Epoch 43/50
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0698 - val_loss: 1.7660
# Epoch 44/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0549 - val_loss: 1.7900
# Epoch 45/50
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0632 - val_loss: 1.7845
# Epoch 46/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0557 - val_loss: 1.7959
# Epoch 47/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0476 - val_loss: 1.7966
# Epoch 48/50
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0461 - val_loss: 1.9396
# Epoch 49/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0651 - val_loss: 1.8112
# Epoch 50/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0285 - val_loss: 1.8321
# Model Evaluation
# 313/313 [==============================] - 1s 2ms/step - loss: 1.8962
# 1.896218180656433

# %% [markdown]
# Define the plot_learning_loss function and plot the loss and val_loss trends

# %%
def plot_learning_loss(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.show()
plot_learning_loss(history)

# %% [markdown]
# ### L1-norm
#
# One possible way to solve the overitting issue is by using regularization methods. The two most common regularization methods in Deep Learning are the L1-norm regularization and the L2-norm regularization. Both These techniques are based on limiting the capacity of models, by adding a parameter norm penalty to the objective function $\mathcal{J}$:
# $$
# \hat{\mathcal{J}}(\theta,\mathbf{X},\mathbf{y}) = \mathcal{J}(\theta,\mathbf{X},\mathbf{y}) + \alpha \Omega(\theta)
# $$
# where $\alpha$ is a hyperparameter that weighs the relative contribution of the norm penalty $\Omega$.
# Lets start by considering the L1-norm regularization where the regularization term is defined as:
# $$
#  \Omega(\theta)=||\mathbf{W}||_1=\sum_i |\mathbf{w}|
# $$
# Let's find the values for the $\alpha$ parameters that allow removing remove the overfitting effect.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))

#In Keras is neccesary to add the regularizer by using the attribute kernel_regularizer
#to each layer whose weights will be considered in the Omega function.
#is it also possibile to consider the bias by using the attribute bias_regularizer 
#tf.keras.regularizers.l1(alpha) perfrom the L1-norm regularization

#To complete: insert the model that you previously define that overfit the 
#trainnig data, and add the L1-norm regularization. Use the proper value for the
#alpha hyper-parameter, that prevents the model from overfitting. In general, a
#layer that exploits L1-norm regularization is defined as follow:

#model.add(keras.layers.Dense(units=To_complete, activation=To_complete,kernel_regularizer=tf.keras.regularizers.l1(To_complete))) 

model.add(keras.layers.Dense(500, activation=tf.nn.leaky_relu, kernel_regularizer=tf.keras.regularizers.l1(0.3)))
model.add(keras.layers.Dense(400, activation="relu", kernel_regularizer=tf.keras.regularizers.l1(0.3)))


model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(1e-3)) #To complete: learning rate

history = model.fit(X_train_small, y_train_small, epochs=30, #To complete: number of epochs
                    validation_data=(X_valid, y_valid))
print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_loss(history)
# Out:
# Epoch 1/30
# 16/16 [==============================] - 1s 50ms/step - loss: 6635.2605 - val_loss: 5669.3970
# Epoch 2/30
# 16/16 [==============================] - 1s 39ms/step - loss: 5470.9442 - val_loss: 4891.2197
# Epoch 3/30
# 16/16 [==============================] - 1s 40ms/step - loss: 4711.2693 - val_loss: 4180.6216
# Epoch 4/30
# 16/16 [==============================] - 1s 37ms/step - loss: 4015.3377 - val_loss: 3528.4253
# Epoch 5/30
# 16/16 [==============================] - 1s 38ms/step - loss: 3377.3916 - val_loss: 2933.3179
# Epoch 6/30
# 16/16 [==============================] - 1s 38ms/step - loss: 2796.3679 - val_loss: 2394.6377
# Epoch 7/30
# 16/16 [==============================] - 1s 38ms/step - loss: 2271.6914 - val_loss: 1912.6776
# Epoch 8/30
# 16/16 [==============================] - 1s 39ms/step - loss: 1803.7601 - val_loss: 1487.7908
# Epoch 9/30
# 16/16 [==============================] - 1s 38ms/step - loss: 1392.7867 - val_loss: 1119.0941
# Epoch 10/30
# 16/16 [==============================] - 1s 39ms/step - loss: 1038.3562 - val_loss: 807.4336
# Epoch 11/30
# 16/16 [==============================] - 1s 38ms/step - loss: 740.5164 - val_loss: 551.7065
# Epoch 12/30
# 16/16 [==============================] - 1s 39ms/step - loss: 499.2159 - val_loss: 353.3222
# Epoch 13/30
# 16/16 [==============================] - 1s 38ms/step - loss: 314.7516 - val_loss: 211.3306
# Epoch 14/30
# 16/16 [==============================] - 1s 38ms/step - loss: 185.9591 - val_loss: 122.8602
# Epoch 15/30
# 16/16 [==============================] - 1s 39ms/step - loss: 109.4980 - val_loss: 79.4243
# Epoch 16/30
# 16/16 [==============================] - 1s 40ms/step - loss: 68.7615 - val_loss: 48.9575
# Epoch 17/30
# 16/16 [==============================] - 1s 39ms/step - loss: 45.2462 - val_loss: 36.2502
# Epoch 18/30
# 16/16 [==============================] - 1s 40ms/step - loss: 34.9535 - val_loss: 32.2684
# Epoch 19/30
# 16/16 [==============================] - 1s 38ms/step - loss: 31.8314 - val_loss: 30.4791
# Epoch 20/30
# 16/16 [==============================] - 1s 39ms/step - loss: 30.3452 - val_loss: 29.9399
# Epoch 21/30
# 16/16 [==============================] - 1s 38ms/step - loss: 29.7194 - val_loss: 29.3947
# Epoch 22/30
# 16/16 [==============================] - 1s 39ms/step - loss: 29.3637 - val_loss: 29.2433
# Epoch 23/30
# 16/16 [==============================] - 1s 38ms/step - loss: 29.2123 - val_loss: 29.1018
# Epoch 24/30
# 16/16 [==============================] - 1s 38ms/step - loss: 29.0905 - val_loss: 29.0392
# Epoch 25/30
# 16/16 [==============================] - 1s 39ms/step - loss: 29.0300 - val_loss: 28.9913
# Epoch 26/30
# 16/16 [==============================] - 1s 38ms/step - loss: 28.9925 - val_loss: 28.9664
# Epoch 27/30
# 16/16 [==============================] - 1s 48ms/step - loss: 28.9709 - val_loss: 28.9591
# Epoch 28/30
# 16/16 [==============================] - 1s 38ms/step - loss: 28.9611 - val_loss: 28.9541
# Epoch 29/30
# 16/16 [==============================] - 1s 40ms/step - loss: 28.9557 - val_loss: 28.9528
# Epoch 30/30
# 16/16 [==============================] - 1s 38ms/step - loss: 28.9513 - val_loss: 28.9519
# Model Evaluation
# 313/313 [==============================] - 1s 3ms/step - loss: 28.9517

# %% [markdown]
# ### L2-norm
#
# L2-norm regularization is also known as weight decay. This strategy drives the weights closer to the origin by adding the regularization term omega which is defined as:
# $$
#  \Omega(\theta)=\frac{1}{2}||\mathbf{W}||_2^2
# $$
#
# Let's find the values for the $\alpha$ parameters that allow removing remove the overfitting effect with L2-norm.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))

#To complete: insert the model that you previously define that overfit the 
#trainnig data, and add the L2-norm regularization. Use the proper value for the
#alpha hyper-parameter, that prevents the model from overfitting. In general, a
#layer that exploits L2-norm regularization is defined as follow:

#model.add(keras.layers.Dense(units=To_complete, activation=To_complete,kernel_regularizer=tf.keras.regularizers.l2(To_complete))) 
model.add(keras.layers.Dense(500, activation=tf.nn.leaky_relu, kernel_regularizer=tf.keras.regularizers.l2(0.8)))
model.add(keras.layers.Dense(400, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.8)))


model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(1e-3)) #To complete: learning rate

history = model.fit(X_train_small, y_train_small, epochs=40, #To complete: that prevents the model from overfitting
                    validation_data=(X_valid, y_valid))
print("Model Evaluation")
model.evaluate(X_test, y_test)
plot_learning_loss(history)
# Out:
# Epoch 1/40
# 16/16 [==============================] - 1s 46ms/step - loss: 1349.7866 - val_loss: 839.6447
# Epoch 2/40
# 16/16 [==============================] - 1s 39ms/step - loss: 809.8533 - val_loss: 771.6534
# Epoch 3/40
# 16/16 [==============================] - 1s 37ms/step - loss: 761.6365 - val_loss: 733.1921
# Epoch 4/40
# 16/16 [==============================] - 1s 37ms/step - loss: 723.3680 - val_loss: 696.3725
# Epoch 5/40
# 16/16 [==============================] - 1s 38ms/step - loss: 687.0045 - val_loss: 661.5286
# Epoch 6/40
# 16/16 [==============================] - 1s 36ms/step - loss: 652.6188 - val_loss: 628.5809
# Epoch 7/40
# 16/16 [==============================] - 1s 38ms/step - loss: 620.0619 - val_loss: 597.1427
# Epoch 8/40
# 16/16 [==============================] - 1s 37ms/step - loss: 589.0520 - val_loss: 567.4249
# Epoch 9/40
# 16/16 [==============================] - 1s 40ms/step - loss: 559.6396 - val_loss: 539.0334
# Epoch 10/40
# 16/16 [==============================] - 1s 41ms/step - loss: 531.7091 - val_loss: 512.1819
# Epoch 11/40
# 16/16 [==============================] - 1s 40ms/step - loss: 505.1252 - val_loss: 486.5557
# Epoch 12/40
# 16/16 [==============================] - 1s 39ms/step - loss: 479.9043 - val_loss: 462.3222
# Epoch 13/40
# 16/16 [==============================] - 1s 38ms/step - loss: 455.9328 - val_loss: 439.2723
# Epoch 14/40
# 16/16 [==============================] - 1s 39ms/step - loss: 433.1593 - val_loss: 417.5364
# Epoch 15/40
# 16/16 [==============================] - 1s 38ms/step - loss: 411.5932 - val_loss: 396.6339
# Epoch 16/40
# 16/16 [==============================] - 1s 38ms/step - loss: 391.0436 - val_loss: 376.7998
# Epoch 17/40
# 16/16 [==============================] - 1s 39ms/step - loss: 371.5078 - val_loss: 358.0777
# Epoch 18/40
# 16/16 [==============================] - 1s 39ms/step - loss: 352.9933 - val_loss: 340.1693
# Epoch 19/40
# 16/16 [==============================] - 1s 41ms/step - loss: 335.3850 - val_loss: 323.2273
# Epoch 20/40
# 16/16 [==============================] - 1s 38ms/step - loss: 318.6351 - val_loss: 307.1722
# Epoch 21/40
# 16/16 [==============================] - 1s 38ms/step - loss: 302.7422 - val_loss: 291.8435
# Epoch 22/40
# 16/16 [==============================] - 1s 41ms/step - loss: 287.6210 - val_loss: 277.4128
# Epoch 23/40
# 16/16 [==============================] - 1s 38ms/step - loss: 273.3076 - val_loss: 263.4885
# Epoch 24/40
# 16/16 [==============================] - 1s 38ms/step - loss: 259.6273 - val_loss: 250.3221
# Epoch 25/40
# 16/16 [==============================] - 1s 36ms/step - loss: 246.7260 - val_loss: 237.9647
# Epoch 26/40
# 16/16 [==============================] - 1s 37ms/step - loss: 234.4249 - val_loss: 226.0901
# Epoch 27/40
# 16/16 [==============================] - 1s 39ms/step - loss: 222.7398 - val_loss: 215.0070
# Epoch 28/40
# 16/16 [==============================] - 1s 41ms/step - loss: 211.6193 - val_loss: 204.1956
# Epoch 29/40
# 16/16 [==============================] - 1s 39ms/step - loss: 201.1342 - val_loss: 193.9268
# Epoch 30/40
# 16/16 [==============================] - 1s 37ms/step - loss: 191.0862 - val_loss: 184.3173
# Epoch 31/40
# 16/16 [==============================] - 1s 37ms/step - loss: 181.5514 - val_loss: 175.1347
# Epoch 32/40
# 16/16 [==============================] - 1s 39ms/step - loss: 172.4995 - val_loss: 166.5987
# Epoch 33/40
# 16/16 [==============================] - 1s 38ms/step - loss: 163.9027 - val_loss: 158.2123
# Epoch 34/40
# 16/16 [==============================] - 1s 38ms/step - loss: 155.8195 - val_loss: 150.3627
# Epoch 35/40
# 16/16 [==============================] - 1s 37ms/step - loss: 148.0170 - val_loss: 142.8461
# Epoch 36/40
# 16/16 [==============================] - 1s 39ms/step - loss: 140.5983 - val_loss: 135.8812
# Epoch 37/40
# 16/16 [==============================] - 1s 37ms/step - loss: 133.8202 - val_loss: 128.9982
# Epoch 38/40
# 16/16 [==============================] - 1s 36ms/step - loss: 126.9355 - val_loss: 122.6163
# Epoch 39/40
# 16/16 [==============================] - 1s 36ms/step - loss: 120.6300 - val_loss: 116.5822
# Epoch 40/40
# 16/16 [==============================] - 1s 38ms/step - loss: 114.6491 - val_loss: 110.8480
# Model Evaluation
# 313/313 [==============================] - 1s 3ms/step - loss: 110.8857

# %% [markdown]
# ### Early stopping
#
# Early Stopping is a form of regularization used to avoid overfitting. It is designed to monitor the generalization error of one model and stop training when generalization error begins to degrade. In order to evaluate the generalization error, early stopping requires that a validation dataset is evaluated during training. Then, when the validation error does not improve for a specific number of epochs (patience hyper-parameter), it stops the training phase.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))

#To complete: insert the model that you previously define that overfit the 
#trainnig data


model.add(keras.layers.Dense(500, activation="relu"))
model.add(keras.layers.Dense(400, activation="relu")) 
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=1e-3)) #To complete: learning rate

#Let's define a log dir in order to save the checkpoint file
logdir = os.path.join(os.curdir, "my_logs", "run_{}".format(time.time()))

#In Keras the Eraly stopping is manage by using the callbacks argument.
callbacks = [
    keras.callbacks.TensorBoard(logdir),
    keras.callbacks.EarlyStopping(patience=5), #To complete: play with patience and find the value that prevents the model from overfitting
    #Saving the checkpoints file allows to load the "best" model when the Early 
    #stopping detect that the generalization error degrade (after 'patience' epochs)
    keras.callbacks.ModelCheckpoint("my_mnist_model.h5", save_best_only=True),
]

history = model.fit(X_train_small, y_train_small, epochs=50, #To complete: number of epochs
                    validation_data=(X_valid_scaled, y_valid),
                    callbacks=callbacks)

print("Model Evaluation")
#The early stopping stopped training after few epochs without progress, so your
#model may already have started to overfit the training set. Since the 
#ModelCheckpoint callback only saved the best models (on the validation set) the
#last saved model is the best on the validation set.
model = keras.models.load_model("my_mnist_model.h5")
model.evaluate(X_test, y_test)
plot_learning_loss(history)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 44ms/step - loss: 265.4713 - val_loss: 2.0548
# Epoch 2/50
# 16/16 [==============================] - 0s 29ms/step - loss: 6.3358 - val_loss: 2.0059
# Epoch 3/50
# 16/16 [==============================] - 0s 31ms/step - loss: 1.8329 - val_loss: 1.9816
# Epoch 4/50
# 16/16 [==============================] - 0s 30ms/step - loss: 1.0511 - val_loss: 1.9778
# Epoch 5/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.7198 - val_loss: 1.9646
# Epoch 6/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.6401 - val_loss: 1.9661
# Epoch 7/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.6238 - val_loss: 1.9544
# Epoch 8/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.6061 - val_loss: 1.9588
# Epoch 9/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.4320 - val_loss: 1.9579
# Epoch 10/50
# 16/16 [==============================] - 0s 31ms/step - loss: 0.4418 - val_loss: 1.9585
# Epoch 11/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.3620 - val_loss: 1.9524
# Epoch 12/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2994 - val_loss: 1.9540
# Epoch 13/50
# 16/16 [==============================] - 0s 28ms/step - loss: 0.2744 - val_loss: 1.9484
# Epoch 14/50
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2675 - val_loss: 1.9501
# Epoch 15/50
# 16/16 [==============================] - 0s 31ms/step - loss: 0.2633 - val_loss: 1.9431
# Epoch 16/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2697 - val_loss: 1.9461
# Epoch 17/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1917 - val_loss: 1.9444
# Epoch 18/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.2143 - val_loss: 1.9466
# Epoch 19/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2314 - val_loss: 1.9414
# Epoch 20/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1663 - val_loss: 1.9389
# Epoch 21/50
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1957 - val_loss: 1.9454
# Epoch 22/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1598 - val_loss: 1.9400
# Epoch 23/50
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1754 - val_loss: 1.9436
# Epoch 24/50
# 16/16 [==============================] - 0s 32ms/step - loss: 0.1528 - val_loss: 1.9450
# Epoch 25/50
# 16/16 [==============================] - 0s 32ms/step - loss: 0.1164 - val_loss: 1.9454
# Model Evaluation
# 313/313 [==============================] - 1s 3ms/step - loss: 2.4868

# %% [markdown]
# ## Exercise 2.3: Model Selection
#
# Hyperparameters are the parameters of the learning method itself which we have to specify a priori, i.e., before model fitting. In contrast, model parameters are parameters which arise as a result of the fit. The aim of the model selection is selecting the best hyperparameters for our deep network. Finding the right hyperparameters for a model can be crucial for the model performance on given data. For istance lets consider our model trained by using different values for the learnign rate:

# %%
learning_rates = [1e-4, 1e-2, 1e-1]

# %%
histories = []
for learning_rate in learning_rates:
    model = keras.models.Sequential([
                                    keras.layers.Flatten(input_shape=[28, 28]),
                                    keras.layers.Dense(300, activation="relu"),
                                    keras.layers.Dense(10, activation="softmax")])

    model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=learning_rate),
              metrics=["accuracy"])
              
    callbacks = [keras.callbacks.EarlyStopping(patience=2)]

    history = model.fit(X_train_scaled, y_train,
                        validation_data=(X_valid_scaled, y_valid), epochs=10,
                        callbacks=callbacks)
    histories.append(history)
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 2.0449 - accuracy: 0.3071 - val_loss: 1.1778 - val_accuracy: 0.6374
# Epoch 2/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 1.1236 - accuracy: 0.6473 - val_loss: 0.9365 - val_accuracy: 0.7046
# Epoch 3/10
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.9338 - accuracy: 0.6999 - val_loss: 0.8292 - val_accuracy: 0.7326
# Epoch 4/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.8375 - accuracy: 0.7291 - val_loss: 0.7640 - val_accuracy: 0.7522
# Epoch 5/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.7837 - accuracy: 0.7423 - val_loss: 0.7192 - val_accuracy: 0.7660
# Epoch 6/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.7323 - accuracy: 0.7570 - val_loss: 0.6856 - val_accuracy: 0.7758
# Epoch 7/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6966 - accuracy: 0.7701 - val_loss: 0.6591 - val_accuracy: 0.7818
# Epoch 8/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6700 - accuracy: 0.7755 - val_loss: 0.6374 - val_accuracy: 0.7872
# Epoch 9/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6539 - accuracy: 0.7798 - val_loss: 0.6194 - val_accuracy: 0.7918
# Epoch 10/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6318 - accuracy: 0.7865 - val_loss: 0.6038 - val_accuracy: 0.7970
# Epoch 1/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.6734 - accuracy: 0.7673 - val_loss: 0.4086 - val_accuracy: 0.8604
# Epoch 2/10
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.3828 - accuracy: 0.8655 - val_loss: 0.3684 - val_accuracy: 0.8724
# Epoch 3/10
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.3421 - accuracy: 0.8803 - val_loss: 0.3627 - val_accuracy: 0.8722
# Epoch 4/10
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.3167 - accuracy: 0.8863 - val_loss: 0.3375 - val_accuracy: 0.8830
# Epoch 5/10
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.3042 - accuracy: 0.8914 - val_loss: 0.3300 - val_accuracy: 0.8846
# Epoch 6/10
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.2751 - accuracy: 0.9020 - val_loss: 0.3290 - val_accuracy: 0.8850
# Epoch 7/10
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.2667 - accuracy: 0.9053 - val_loss: 0.3234 - val_accuracy: 0.8874
# Epoch 8/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2505 - accuracy: 0.9118 - val_loss: 0.3273 - val_accuracy: 0.8802
# Epoch 9/10
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.2474 - accuracy: 0.9102 - val_loss: 0.3137 - val_accuracy: 0.8900
# Epoch 10/10
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.2310 - accuracy: 0.9174 - val_loss: 0.3109 - val_accuracy: 0.8912
# Epoch 1/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5747 - accuracy: 0.8039 - val_loss: 0.4205 - val_accuracy: 0.8590
# Epoch 2/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3543 - accuracy: 0.8725 - val_loss: 0.3651 - val_accuracy: 0.8732
# Epoch 3/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3035 - accuracy: 0.8897 - val_loss: 0.4263 - val_accuracy: 0.8584
# Epoch 4/10
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2749 - accuracy: 0.9000 - val_loss: 0.3472 - val_accuracy: 0.8830
# Epoch 5/10
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.2553 - accuracy: 0.9053 - val_loss: 0.3573 - val_accuracy: 0.8890
# Epoch 6/10
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.2216 - accuracy: 0.9191 - val_loss: 0.3645 - val_accuracy: 0.8832

# %% [markdown]
# Let's plot the results

# %%
for learning_rate, history in zip(learning_rates, histories):
    print("Learning rate:", learning_rate)
    plot_learning_curves(history)
# Out:
# Learning rate: 0.0001
# Learning rate: 0.01
# Learning rate: 0.1

# %% [markdown]
# Note that the learning rate influence significantly the training phase. That behavior suggests that is crucial to validate the hyper-parameters to obtain good results.

# %% [markdown]
# ### GRID Search:
#
# Since a deep net has many hyperparameters, in order to find the best ones, we have to consider all the possible combinations of all of the possible values. One common method to perform this complex task is Grid-Search.
# Given a set of values for each hyper-parameter, Grid-Search will build a model on each parameter combination possible. It iterates through every parameter combination and stores a model for each combination. Finally, the model that obtained the best result on the validation set will be select.
#
# In order to perfrom Grid-Search we will use GridSearchCV method from scikit-learn.

# %% [markdown]
# Let's Create a build_model() function that takes two arguments, n_units and learning_rate, and builds, compiles and returns a model with the given number of of neurons and the given learning rate.
# In order to limit the time demends of the proces we will consider only this two hyper-paramters and a small 3 layer model.

# %%
def build_model(n_units=30, learning_rate=1e-3):

  #To complete:
  #HINT: the function has to build the model with 3 layers:
  #- a Flatten layer to convert each 28x28 image to a single row 
  #- a Danse layer composed of n_units and that exploits Relu activation function 
  #- the output layer that uses the softmax activation function
  #Then, has to be defined how the model will be compiled.
    model = keras.models.Sequential([
                                    keras.layers.Flatten(input_shape=[28, 28]),
                                    keras.layers.Dense(n_units, activation="relu"),
                                    keras.layers.Dense(10, activation="softmax")])

    model.compile(loss="sparse_categorical_crossentropy",
              optimizer=keras.optimizers.SGD(lr=learning_rate),
              metrics=["accuracy"])
    
    return model

    
#Create a keras.wrappers.scikit_learn.KerasRegressor and pass the build_model 
#function to the constructor. This gives you a Scikit-Learn compatible predictor
keras_reg = keras.wrappers.scikit_learn.KerasRegressor(build_model)

# %% [markdown]
# Let's define the lists of hyper-parameters' values. Also in this case, we use a very limited size lists, but in a real-world scenario a reasonable amount of possible values should be considered (try to add some values and check how much the time required to perform the Grid-Search increases)

# %%
param_distribs = {
    "n_units": [100, 300, 500],# To_complete: insert a few (2 or 3) reasonable values  
    "learning_rate": [1e-4, 1e-2, 1e-1] # To_complete: insert a few (2 or 3) reasonable values
 }
    #Check how much increase the time required to perform GRID search increasing
    #the number of the values for each hyper-parameter.

# %% [markdown]
# Use a sklearn.model_selection.GridSearchCV to search the hyperparameter space of your KerasRegressor

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(keras_reg, param_distribs)

# %% [markdown]
# Run the Grid-Search

# %%
grid_search.fit(X_train_scaled, y_train, epochs=10, #The number of epochs can be modified (check what happens by increasing it) 
                  validation_data=(X_valid_scaled, y_valid))
# Out:
# Epoch 1/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 2.3870 - accuracy: 0.2016 - val_loss: 1.5077 - val_accuracy: 0.4892
# Epoch 2/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 1.4036 - accuracy: 0.5212 - val_loss: 1.1489 - val_accuracy: 0.6204
# Epoch 3/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 1.1104 - accuracy: 0.6296 - val_loss: 0.9919 - val_accuracy: 0.6684
# Epoch 4/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.9715 - accuracy: 0.6788 - val_loss: 0.9010 - val_accuracy: 0.6966
# Epoch 5/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.8967 - accuracy: 0.7030 - val_loss: 0.8402 - val_accuracy: 0.7166
# Epoch 6/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.8356 - accuracy: 0.7175 - val_loss: 0.7957 - val_accuracy: 0.7320
# Epoch 7/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7915 - accuracy: 0.7338 - val_loss: 0.7613 - val_accuracy: 0.7422
# Epoch 8/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7696 - accuracy: 0.7389 - val_loss: 0.7336 - val_accuracy: 0.7506
# Epoch 9/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7429 - accuracy: 0.7459 - val_loss: 0.7106 - val_accuracy: 0.7578
# Epoch 10/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7195 - accuracy: 0.7541 - val_loss: 0.6909 - val_accuracy: 0.7648
# 344/344 [==============================] - 0s 1ms/step - loss: 0.7059 - accuracy: 0.7559
# Epoch 1/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 2.7449 - accuracy: 0.1631 - val_loss: 1.5608 - val_accuracy: 0.4778
# Epoch 2/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 1.4358 - accuracy: 0.5152 - val_loss: 1.1582 - val_accuracy: 0.6160
# Epoch 3/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 1.1254 - accuracy: 0.6234 - val_loss: 1.0001 - val_accuracy: 0.6712
# Epoch 4/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.9835 - accuracy: 0.6708 - val_loss: 0.9102 - val_accuracy: 0.7026
# Epoch 5/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.9090 - accuracy: 0.6976 - val_loss: 0.8501 - val_accuracy: 0.7238
# Epoch 6/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.8447 - accuracy: 0.7177 - val_loss: 0.8062 - val_accuracy: 0.7364
# Epoch 7/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.8063 - accuracy: 0.7289 - val_loss: 0.7723 - val_accuracy: 0.7444
# Epoch 8/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7765 - accuracy: 0.7418 - val_loss: 0.7448 - val_accuracy: 0.7516
# Epoch 9/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7587 - accuracy: 0.7481 - val_loss: 0.7219 - val_accuracy: 0.7578
# Epoch 10/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7219 - accuracy: 0.7574 - val_loss: 0.7023 - val_accuracy: 0.7652
# 344/344 [==============================] - 0s 1ms/step - loss: 0.7273 - accuracy: 0.7552
# Epoch 1/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 2.2374 - accuracy: 0.2442 - val_loss: 1.3824 - val_accuracy: 0.5392
# Epoch 2/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 1.2841 - accuracy: 0.5770 - val_loss: 1.0661 - val_accuracy: 0.6610
# Epoch 3/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 1.0325 - accuracy: 0.6671 - val_loss: 0.9369 - val_accuracy: 0.7028
# Epoch 4/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.9163 - accuracy: 0.7009 - val_loss: 0.8616 - val_accuracy: 0.7230
# Epoch 5/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.8482 - accuracy: 0.7206 - val_loss: 0.8101 - val_accuracy: 0.7400
# Epoch 6/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7983 - accuracy: 0.7339 - val_loss: 0.7720 - val_accuracy: 0.7522
# Epoch 7/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7693 - accuracy: 0.7430 - val_loss: 0.7423 - val_accuracy: 0.7586
# Epoch 8/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7388 - accuracy: 0.7523 - val_loss: 0.7182 - val_accuracy: 0.7682
# Epoch 9/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7245 - accuracy: 0.7592 - val_loss: 0.6982 - val_accuracy: 0.7748
# Epoch 10/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.6916 - accuracy: 0.7683 - val_loss: 0.6809 - val_accuracy: 0.7790
# 344/344 [==============================] - 0s 1ms/step - loss: 0.6850 - accuracy: 0.7678
# Epoch 1/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 2.5390 - accuracy: 0.1703 - val_loss: 1.5666 - val_accuracy: 0.4912
# Epoch 2/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 1.4543 - accuracy: 0.5322 - val_loss: 1.1721 - val_accuracy: 0.6362
# Epoch 3/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 1.1411 - accuracy: 0.6373 - val_loss: 1.0114 - val_accuracy: 0.6826
# Epoch 4/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 1.0006 - accuracy: 0.6777 - val_loss: 0.9180 - val_accuracy: 0.7028
# Epoch 5/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.9183 - accuracy: 0.6985 - val_loss: 0.8545 - val_accuracy: 0.7178
# Epoch 6/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.8613 - accuracy: 0.7136 - val_loss: 0.8076 - val_accuracy: 0.7308
# Epoch 7/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.8182 - accuracy: 0.7272 - val_loss: 0.7709 - val_accuracy: 0.7442
# Epoch 8/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7803 - accuracy: 0.7377 - val_loss: 0.7414 - val_accuracy: 0.7516
# Epoch 9/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.7586 - accuracy: 0.7431 - val_loss: 0.7169 - val_accuracy: 0.7566
# Epoch 10/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.7292 - accuracy: 0.7514 - val_loss: 0.6960 - val_accuracy: 0.7636
# 344/344 [==============================] - 0s 1ms/step - loss: 0.7096 - accuracy: 0.7582
# Epoch 1/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 2.2262 - accuracy: 0.2151 - val_loss: 1.4275 - val_accuracy: 0.5458
# Epoch 2/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 1.3603 - accuracy: 0.5591 - val_loss: 1.1020 - val_accuracy: 0.6530
# Epoch 3/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 1.0875 - accuracy: 0.6520 - val_loss: 0.9600 - val_accuracy: 0.6940
# Epoch 4/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.9632 - accuracy: 0.6926 - val_loss: 0.8771 - val_accuracy: 0.7152
# Epoch 5/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.8875 - accuracy: 0.7085 - val_loss: 0.8202 - val_accuracy: 0.7324
# Epoch 6/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.8335 - accuracy: 0.7265 - val_loss: 0.7779 - val_accuracy: 0.7458
# Epoch 7/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.8003 - accuracy: 0.7368 - val_loss: 0.7445 - val_accuracy: 0.7590
# Epoch 8/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7616 - accuracy: 0.7505 - val_loss: 0.7175 - val_accuracy: 0.7660
# Epoch 9/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7458 - accuracy: 0.7556 - val_loss: 0.6948 - val_accuracy: 0.7726
# Epoch 10/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.7114 - accuracy: 0.7651 - val_loss: 0.6754 - val_accuracy: 0.7782
# 344/344 [==============================] - 0s 1ms/step - loss: 0.7010 - accuracy: 0.7653
# Epoch 1/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 2.2996 - accuracy: 0.2506 - val_loss: 1.3443 - val_accuracy: 0.5868
# Epoch 2/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 1.2607 - accuracy: 0.6108 - val_loss: 1.0356 - val_accuracy: 0.6680
# Epoch 3/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 1.0221 - accuracy: 0.6694 - val_loss: 0.9034 - val_accuracy: 0.6998
# Epoch 4/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.9051 - accuracy: 0.7027 - val_loss: 0.8255 - val_accuracy: 0.7232
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.8314 - accuracy: 0.7191 - val_loss: 0.7722 - val_accuracy: 0.7398
# Epoch 6/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7838 - accuracy: 0.7350 - val_loss: 0.7330 - val_accuracy: 0.7542
# Epoch 7/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7402 - accuracy: 0.7483 - val_loss: 0.7024 - val_accuracy: 0.7644
# Epoch 8/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7179 - accuracy: 0.7575 - val_loss: 0.6777 - val_accuracy: 0.7722
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.6996 - accuracy: 0.7619 - val_loss: 0.6571 - val_accuracy: 0.7780
# Epoch 10/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.6720 - accuracy: 0.7728 - val_loss: 0.6394 - val_accuracy: 0.7826
# 344/344 [==============================] - 1s 1ms/step - loss: 0.6668 - accuracy: 0.7700
# Epoch 1/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 2.2300 - accuracy: 0.2403 - val_loss: 1.3364 - val_accuracy: 0.5614
# Epoch 2/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 1.2519 - accuracy: 0.5761 - val_loss: 1.0495 - val_accuracy: 0.6534
# Epoch 3/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 1.0261 - accuracy: 0.6477 - val_loss: 0.9225 - val_accuracy: 0.6894
# Epoch 4/10
# 1375/1375 [==============================] - 3s 3ms/step - loss: 0.9086 - accuracy: 0.6891 - val_loss: 0.8461 - val_accuracy: 0.7142
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.8474 - accuracy: 0.7093 - val_loss: 0.7931 - val_accuracy: 0.7308
# Epoch 6/10
# 1375/1375 [==============================] - 3s 3ms/step - loss: 0.7872 - accuracy: 0.7305 - val_loss: 0.7535 - val_accuracy: 0.7450
# Epoch 7/10
# 1375/1375 [==============================] - 3s 3ms/step - loss: 0.7586 - accuracy: 0.7375 - val_loss: 0.7225 - val_accuracy: 0.7572
# Epoch 8/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7281 - accuracy: 0.7530 - val_loss: 0.6972 - val_accuracy: 0.7674
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7131 - accuracy: 0.7553 - val_loss: 0.6760 - val_accuracy: 0.7714
# Epoch 10/10
# 1375/1375 [==============================] - 3s 3ms/step - loss: 0.6799 - accuracy: 0.7657 - val_loss: 0.6578 - val_accuracy: 0.7770
# 344/344 [==============================] - 1s 1ms/step - loss: 0.6859 - accuracy: 0.7689
# Epoch 1/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 2.2138 - accuracy: 0.2735 - val_loss: 1.2515 - val_accuracy: 0.6164
# Epoch 2/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 1.1838 - accuracy: 0.6253 - val_loss: 0.9793 - val_accuracy: 0.6904
# Epoch 3/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.9647 - accuracy: 0.6841 - val_loss: 0.8674 - val_accuracy: 0.7196
# Epoch 4/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.8636 - accuracy: 0.7139 - val_loss: 0.8018 - val_accuracy: 0.7364
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.8012 - accuracy: 0.7300 - val_loss: 0.7567 - val_accuracy: 0.7464
# Epoch 6/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7586 - accuracy: 0.7433 - val_loss: 0.7235 - val_accuracy: 0.7578
# Epoch 7/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7322 - accuracy: 0.7509 - val_loss: 0.6974 - val_accuracy: 0.7684
# Epoch 8/10
# 1375/1375 [==============================] - 3s 3ms/step - loss: 0.7037 - accuracy: 0.7607 - val_loss: 0.6760 - val_accuracy: 0.7758
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.6897 - accuracy: 0.7664 - val_loss: 0.6581 - val_accuracy: 0.7806
# Epoch 10/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.6616 - accuracy: 0.7741 - val_loss: 0.6426 - val_accuracy: 0.7834
# 344/344 [==============================] - 1s 2ms/step - loss: 0.6546 - accuracy: 0.7755
# Epoch 1/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 2.4732 - accuracy: 0.1840 - val_loss: 1.3783 - val_accuracy: 0.5668
# Epoch 2/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 1.2906 - accuracy: 0.5906 - val_loss: 1.0547 - val_accuracy: 0.6692
# Epoch 3/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 1.0280 - accuracy: 0.6717 - val_loss: 0.9170 - val_accuracy: 0.7064
# Epoch 4/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.9075 - accuracy: 0.7055 - val_loss: 0.8366 - val_accuracy: 0.7314
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.8383 - accuracy: 0.7266 - val_loss: 0.7823 - val_accuracy: 0.7474
# Epoch 6/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7890 - accuracy: 0.7398 - val_loss: 0.7425 - val_accuracy: 0.7588
# Epoch 7/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7492 - accuracy: 0.7542 - val_loss: 0.7116 - val_accuracy: 0.7670
# Epoch 8/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7169 - accuracy: 0.7618 - val_loss: 0.6867 - val_accuracy: 0.7722
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7000 - accuracy: 0.7669 - val_loss: 0.6660 - val_accuracy: 0.7786
# Epoch 10/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.6721 - accuracy: 0.7772 - val_loss: 0.6483 - val_accuracy: 0.7828
# 344/344 [==============================] - 1s 1ms/step - loss: 0.6572 - accuracy: 0.7798
# Epoch 1/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 2.1766 - accuracy: 0.2688 - val_loss: 1.3214 - val_accuracy: 0.5792
# Epoch 2/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 1.2453 - accuracy: 0.5959 - val_loss: 1.0227 - val_accuracy: 0.6714
# Epoch 3/10
# 1375/1375 [==============================] - 3s 3ms/step - loss: 1.0039 - accuracy: 0.6723 - val_loss: 0.8916 - val_accuracy: 0.7094
# Epoch 4/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.8884 - accuracy: 0.7074 - val_loss: 0.8145 - val_accuracy: 0.7328
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.8221 - accuracy: 0.7250 - val_loss: 0.7622 - val_accuracy: 0.7514
# Epoch 6/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7742 - accuracy: 0.7443 - val_loss: 0.7238 - val_accuracy: 0.7624
# Epoch 7/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7431 - accuracy: 0.7523 - val_loss: 0.6940 - val_accuracy: 0.7730
# Epoch 8/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7135 - accuracy: 0.7627 - val_loss: 0.6700 - val_accuracy: 0.7814
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.6960 - accuracy: 0.7672 - val_loss: 0.6500 - val_accuracy: 0.7856
# Epoch 10/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.6677 - accuracy: 0.7764 - val_loss: 0.6332 - val_accuracy: 0.7902
# 344/344 [==============================] - 1s 1ms/step - loss: 0.6553 - accuracy: 0.7750
# Epoch 1/10
# 1375/1375 [==============================] - 5s 3ms/step - loss: 2.1985 - accuracy: 0.2334 - val_loss: 1.3181 - val_accuracy: 0.5832
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 1.2301 - accuracy: 0.6035 - val_loss: 1.0230 - val_accuracy: 0.6752
# Epoch 3/10
# 1375/1375 [==============================] - 5s 3ms/step - loss: 0.9926 - accuracy: 0.6768 - val_loss: 0.8915 - val_accuracy: 0.7158
# Epoch 4/10
# 1375/1375 [==============================] - 5s 3ms/step - loss: 0.8763 - accuracy: 0.7109 - val_loss: 0.8147 - val_accuracy: 0.7366
# Epoch 5/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.8058 - accuracy: 0.7356 - val_loss: 0.7629 - val_accuracy: 0.7508
# Epoch 6/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7590 - accuracy: 0.7491 - val_loss: 0.7251 - val_accuracy: 0.7632
# Epoch 7/10
# 1375/1375 [==============================] - 5s 3ms/step - loss: 0.7211 - accuracy: 0.7608 - val_loss: 0.6959 - val_accuracy: 0.7720
# Epoch 8/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7011 - accuracy: 0.7704 - val_loss: 0.6723 - val_accuracy: 0.7780
# Epoch 9/10
# 1375/1375 [==============================] - 5s 3ms/step - loss: 0.6794 - accuracy: 0.7743 - val_loss: 0.6526 - val_accuracy: 0.7824
# Epoch 10/10
# 1375/1375 [==============================] - 5s 3ms/step - loss: 0.6564 - accuracy: 0.7812 - val_loss: 0.6357 - val_accuracy: 0.7880
# 344/344 [==============================] - 1s 2ms/step - loss: 0.6534 - accuracy: 0.7768
# Epoch 1/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 2.0846 - accuracy: 0.2860 - val_loss: 1.2502 - val_accuracy: 0.6110
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 1.1635 - accuracy: 0.6320 - val_loss: 0.9766 - val_accuracy: 0.6904
# Epoch 3/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.9540 - accuracy: 0.6920 - val_loss: 0.8585 - val_accuracy: 0.7220
# Epoch 4/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.8402 - accuracy: 0.7271 - val_loss: 0.7889 - val_accuracy: 0.7404
# Epoch 5/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7886 - accuracy: 0.7404 - val_loss: 0.7414 - val_accuracy: 0.7554
# Epoch 6/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7349 - accuracy: 0.7542 - val_loss: 0.7062 - val_accuracy: 0.7650
# Epoch 7/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7056 - accuracy: 0.7629 - val_loss: 0.6787 - val_accuracy: 0.7744
# Epoch 8/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6830 - accuracy: 0.7701 - val_loss: 0.6561 - val_accuracy: 0.7800
# Epoch 9/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6617 - accuracy: 0.7768 - val_loss: 0.6370 - val_accuracy: 0.7862
# Epoch 10/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6363 - accuracy: 0.7859 - val_loss: 0.6207 - val_accuracy: 0.7908
# 344/344 [==============================] - 1s 2ms/step - loss: 0.6441 - accuracy: 0.7831
# Epoch 1/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 2.3611 - accuracy: 0.2088 - val_loss: 1.2948 - val_accuracy: 0.6110
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 1.2052 - accuracy: 0.6301 - val_loss: 0.9895 - val_accuracy: 0.6928
# Epoch 3/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.9678 - accuracy: 0.6925 - val_loss: 0.8675 - val_accuracy: 0.7234
# Epoch 4/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.8566 - accuracy: 0.7227 - val_loss: 0.7982 - val_accuracy: 0.7404
# Epoch 5/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7974 - accuracy: 0.7350 - val_loss: 0.7513 - val_accuracy: 0.7558
# Epoch 6/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7539 - accuracy: 0.7458 - val_loss: 0.7170 - val_accuracy: 0.7650
# Epoch 7/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7258 - accuracy: 0.7538 - val_loss: 0.6902 - val_accuracy: 0.7728
# Epoch 8/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6958 - accuracy: 0.7658 - val_loss: 0.6681 - val_accuracy: 0.7768
# Epoch 9/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6823 - accuracy: 0.7695 - val_loss: 0.6495 - val_accuracy: 0.7828
# Epoch 10/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6546 - accuracy: 0.7782 - val_loss: 0.6334 - val_accuracy: 0.7876
# 344/344 [==============================] - 1s 2ms/step - loss: 0.6487 - accuracy: 0.7774
# Epoch 1/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 2.1530 - accuracy: 0.2575 - val_loss: 1.2480 - val_accuracy: 0.6220
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 1.1739 - accuracy: 0.6306 - val_loss: 0.9781 - val_accuracy: 0.6932
# Epoch 3/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.9544 - accuracy: 0.6879 - val_loss: 0.8586 - val_accuracy: 0.7216
# Epoch 4/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.8524 - accuracy: 0.7221 - val_loss: 0.7878 - val_accuracy: 0.7406
# Epoch 5/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7892 - accuracy: 0.7347 - val_loss: 0.7393 - val_accuracy: 0.7554
# Epoch 6/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7446 - accuracy: 0.7541 - val_loss: 0.7039 - val_accuracy: 0.7672
# Epoch 7/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7205 - accuracy: 0.7599 - val_loss: 0.6762 - val_accuracy: 0.7762
# Epoch 8/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6875 - accuracy: 0.7701 - val_loss: 0.6539 - val_accuracy: 0.7830
# Epoch 9/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6725 - accuracy: 0.7742 - val_loss: 0.6353 - val_accuracy: 0.7906
# Epoch 10/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6469 - accuracy: 0.7833 - val_loss: 0.6195 - val_accuracy: 0.7944
# 344/344 [==============================] - 1s 2ms/step - loss: 0.6327 - accuracy: 0.7853
# Epoch 1/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 2.3589 - accuracy: 0.1877 - val_loss: 1.3006 - val_accuracy: 0.6060
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 1.2219 - accuracy: 0.6199 - val_loss: 0.9961 - val_accuracy: 0.6934
# Epoch 3/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.9797 - accuracy: 0.6875 - val_loss: 0.8699 - val_accuracy: 0.7282
# Epoch 4/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.8664 - accuracy: 0.7218 - val_loss: 0.7970 - val_accuracy: 0.7472
# Epoch 5/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.8041 - accuracy: 0.7391 - val_loss: 0.7474 - val_accuracy: 0.7622
# Epoch 6/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7587 - accuracy: 0.7535 - val_loss: 0.7109 - val_accuracy: 0.7728
# Epoch 7/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7261 - accuracy: 0.7632 - val_loss: 0.6820 - val_accuracy: 0.7816
# Epoch 8/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6950 - accuracy: 0.7726 - val_loss: 0.6589 - val_accuracy: 0.7880
# Epoch 9/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6802 - accuracy: 0.7773 - val_loss: 0.6394 - val_accuracy: 0.7944
# Epoch 10/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6511 - accuracy: 0.7855 - val_loss: 0.6228 - val_accuracy: 0.7984
# 344/344 [==============================] - 1s 2ms/step - loss: 0.6388 - accuracy: 0.7854
# Epoch 1/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.7605 - accuracy: 0.7426 - val_loss: 0.4309 - val_accuracy: 0.8504
# Epoch 2/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.4177 - accuracy: 0.8516 - val_loss: 0.3905 - val_accuracy: 0.8656
# Epoch 3/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.3724 - accuracy: 0.8685 - val_loss: 0.3762 - val_accuracy: 0.8692
# Epoch 4/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3411 - accuracy: 0.8799 - val_loss: 0.3709 - val_accuracy: 0.8726
# Epoch 5/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3213 - accuracy: 0.8836 - val_loss: 0.3523 - val_accuracy: 0.8778
# Epoch 6/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3056 - accuracy: 0.8914 - val_loss: 0.3512 - val_accuracy: 0.8774
# Epoch 7/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2963 - accuracy: 0.8953 - val_loss: 0.3414 - val_accuracy: 0.8838
# Epoch 8/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2861 - accuracy: 0.8991 - val_loss: 0.3445 - val_accuracy: 0.8810
# Epoch 9/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2787 - accuracy: 0.9001 - val_loss: 0.3364 - val_accuracy: 0.8820
# Epoch 10/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2646 - accuracy: 0.9052 - val_loss: 0.3379 - val_accuracy: 0.8844
# 344/344 [==============================] - 0s 1ms/step - loss: 0.3428 - accuracy: 0.8774
# Epoch 1/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.7702 - accuracy: 0.7359 - val_loss: 0.4469 - val_accuracy: 0.8422
# Epoch 2/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.4191 - accuracy: 0.8482 - val_loss: 0.4007 - val_accuracy: 0.8582
# Epoch 3/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3704 - accuracy: 0.8688 - val_loss: 0.3797 - val_accuracy: 0.8656
# Epoch 4/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3411 - accuracy: 0.8795 - val_loss: 0.3724 - val_accuracy: 0.8688
# Epoch 5/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3250 - accuracy: 0.8845 - val_loss: 0.3568 - val_accuracy: 0.8746
# Epoch 6/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3108 - accuracy: 0.8885 - val_loss: 0.3563 - val_accuracy: 0.8720
# Epoch 7/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3005 - accuracy: 0.8927 - val_loss: 0.3530 - val_accuracy: 0.8760
# Epoch 8/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2880 - accuracy: 0.8973 - val_loss: 0.3481 - val_accuracy: 0.8766
# Epoch 9/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2810 - accuracy: 0.8995 - val_loss: 0.3442 - val_accuracy: 0.8788
# Epoch 10/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2662 - accuracy: 0.9057 - val_loss: 0.3456 - val_accuracy: 0.8786
# 344/344 [==============================] - 0s 1ms/step - loss: 0.3480 - accuracy: 0.8741
# Epoch 1/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.7431 - accuracy: 0.7439 - val_loss: 0.4457 - val_accuracy: 0.8438
# Epoch 2/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.4226 - accuracy: 0.8487 - val_loss: 0.4020 - val_accuracy: 0.8574
# Epoch 3/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3663 - accuracy: 0.8682 - val_loss: 0.3828 - val_accuracy: 0.8646
# Epoch 4/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3396 - accuracy: 0.8786 - val_loss: 0.3718 - val_accuracy: 0.8718
# Epoch 5/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3244 - accuracy: 0.8833 - val_loss: 0.3595 - val_accuracy: 0.8756
# Epoch 6/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3121 - accuracy: 0.8882 - val_loss: 0.3657 - val_accuracy: 0.8674
# Epoch 7/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3001 - accuracy: 0.8960 - val_loss: 0.3565 - val_accuracy: 0.8748
# Epoch 8/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2848 - accuracy: 0.8972 - val_loss: 0.3471 - val_accuracy: 0.8776
# Epoch 9/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2811 - accuracy: 0.9000 - val_loss: 0.3448 - val_accuracy: 0.8766
# Epoch 10/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2657 - accuracy: 0.9056 - val_loss: 0.3419 - val_accuracy: 0.8780
# 344/344 [==============================] - 0s 1ms/step - loss: 0.3370 - accuracy: 0.8782
# Epoch 1/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.7684 - accuracy: 0.7433 - val_loss: 0.4441 - val_accuracy: 0.8466
# Epoch 2/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.4199 - accuracy: 0.8490 - val_loss: 0.3979 - val_accuracy: 0.8620
# Epoch 3/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3643 - accuracy: 0.8696 - val_loss: 0.3791 - val_accuracy: 0.8656
# Epoch 4/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3480 - accuracy: 0.8757 - val_loss: 0.3626 - val_accuracy: 0.8752
# Epoch 5/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3224 - accuracy: 0.8833 - val_loss: 0.3536 - val_accuracy: 0.8770
# Epoch 6/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3161 - accuracy: 0.8858 - val_loss: 0.3534 - val_accuracy: 0.8748
# Epoch 7/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3048 - accuracy: 0.8911 - val_loss: 0.3426 - val_accuracy: 0.8794
# Epoch 8/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2828 - accuracy: 0.8982 - val_loss: 0.3419 - val_accuracy: 0.8814
# Epoch 9/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2796 - accuracy: 0.8976 - val_loss: 0.3328 - val_accuracy: 0.8816
# Epoch 10/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2706 - accuracy: 0.9023 - val_loss: 0.3313 - val_accuracy: 0.8840
# 344/344 [==============================] - 0s 1ms/step - loss: 0.3293 - accuracy: 0.8855
# Epoch 1/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.7744 - accuracy: 0.7356 - val_loss: 0.4361 - val_accuracy: 0.8508
# Epoch 2/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.4153 - accuracy: 0.8522 - val_loss: 0.3972 - val_accuracy: 0.8620
# Epoch 3/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3643 - accuracy: 0.8692 - val_loss: 0.3733 - val_accuracy: 0.8664
# Epoch 4/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3493 - accuracy: 0.8764 - val_loss: 0.3707 - val_accuracy: 0.8684
# Epoch 5/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3222 - accuracy: 0.8855 - val_loss: 0.3581 - val_accuracy: 0.8730
# Epoch 6/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3152 - accuracy: 0.8877 - val_loss: 0.3560 - val_accuracy: 0.8770
# Epoch 7/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.3018 - accuracy: 0.8938 - val_loss: 0.3487 - val_accuracy: 0.8768
# Epoch 8/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2824 - accuracy: 0.8995 - val_loss: 0.3435 - val_accuracy: 0.8800
# Epoch 9/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2777 - accuracy: 0.9021 - val_loss: 0.3393 - val_accuracy: 0.8804
# Epoch 10/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2694 - accuracy: 0.9055 - val_loss: 0.3356 - val_accuracy: 0.8850
# 344/344 [==============================] - 0s 1ms/step - loss: 0.3443 - accuracy: 0.8750
# Epoch 1/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7092 - accuracy: 0.7579 - val_loss: 0.4189 - val_accuracy: 0.8578
# Epoch 2/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.4005 - accuracy: 0.8572 - val_loss: 0.3828 - val_accuracy: 0.8678
# Epoch 3/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3555 - accuracy: 0.8754 - val_loss: 0.3663 - val_accuracy: 0.8748
# Epoch 4/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3222 - accuracy: 0.8856 - val_loss: 0.3624 - val_accuracy: 0.8720
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3022 - accuracy: 0.8937 - val_loss: 0.3479 - val_accuracy: 0.8804
# Epoch 6/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2859 - accuracy: 0.8993 - val_loss: 0.3458 - val_accuracy: 0.8776
# Epoch 7/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2751 - accuracy: 0.9019 - val_loss: 0.3367 - val_accuracy: 0.8826
# Epoch 8/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2643 - accuracy: 0.9048 - val_loss: 0.3393 - val_accuracy: 0.8838
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2534 - accuracy: 0.9098 - val_loss: 0.3351 - val_accuracy: 0.8822
# Epoch 10/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2401 - accuracy: 0.9155 - val_loss: 0.3330 - val_accuracy: 0.8820
# 344/344 [==============================] - 1s 3ms/step - loss: 0.3274 - accuracy: 0.8816
# Epoch 1/10
# 1375/1375 [==============================] - 5s 3ms/step - loss: 0.7351 - accuracy: 0.7495 - val_loss: 0.4281 - val_accuracy: 0.8538
# Epoch 2/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.4041 - accuracy: 0.8569 - val_loss: 0.3812 - val_accuracy: 0.8656
# Epoch 3/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3525 - accuracy: 0.8745 - val_loss: 0.3652 - val_accuracy: 0.8742
# Epoch 4/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3215 - accuracy: 0.8877 - val_loss: 0.3588 - val_accuracy: 0.8786
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3050 - accuracy: 0.8913 - val_loss: 0.3434 - val_accuracy: 0.8810
# Epoch 6/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2890 - accuracy: 0.8980 - val_loss: 0.3497 - val_accuracy: 0.8804
# Epoch 7/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2762 - accuracy: 0.9038 - val_loss: 0.3436 - val_accuracy: 0.8800
# Epoch 8/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2622 - accuracy: 0.9077 - val_loss: 0.3391 - val_accuracy: 0.8836
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2555 - accuracy: 0.9098 - val_loss: 0.3361 - val_accuracy: 0.8828
# Epoch 10/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2398 - accuracy: 0.9167 - val_loss: 0.3337 - val_accuracy: 0.8814
# 344/344 [==============================] - 1s 2ms/step - loss: 0.3364 - accuracy: 0.8788
# Epoch 1/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7246 - accuracy: 0.7529 - val_loss: 0.4239 - val_accuracy: 0.8516
# Epoch 2/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.4056 - accuracy: 0.8554 - val_loss: 0.3828 - val_accuracy: 0.8690
# Epoch 3/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3484 - accuracy: 0.8763 - val_loss: 0.3624 - val_accuracy: 0.8740
# Epoch 4/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3194 - accuracy: 0.8886 - val_loss: 0.3529 - val_accuracy: 0.8792
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3021 - accuracy: 0.8909 - val_loss: 0.3397 - val_accuracy: 0.8838
# Epoch 6/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2887 - accuracy: 0.8964 - val_loss: 0.3457 - val_accuracy: 0.8744
# Epoch 7/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2741 - accuracy: 0.9028 - val_loss: 0.3364 - val_accuracy: 0.8826
# Epoch 8/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2574 - accuracy: 0.9080 - val_loss: 0.3281 - val_accuracy: 0.8846
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2545 - accuracy: 0.9089 - val_loss: 0.3217 - val_accuracy: 0.8856
# Epoch 10/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2389 - accuracy: 0.9163 - val_loss: 0.3200 - val_accuracy: 0.8870
# 344/344 [==============================] - 1s 2ms/step - loss: 0.3206 - accuracy: 0.8842
# Epoch 1/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7327 - accuracy: 0.7513 - val_loss: 0.4263 - val_accuracy: 0.8496
# Epoch 2/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.4040 - accuracy: 0.8579 - val_loss: 0.3871 - val_accuracy: 0.8652
# Epoch 3/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3459 - accuracy: 0.8789 - val_loss: 0.3618 - val_accuracy: 0.8716
# Epoch 4/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3281 - accuracy: 0.8844 - val_loss: 0.3538 - val_accuracy: 0.8752
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3022 - accuracy: 0.8915 - val_loss: 0.3432 - val_accuracy: 0.8772
# Epoch 6/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2949 - accuracy: 0.8942 - val_loss: 0.3426 - val_accuracy: 0.8764
# Epoch 7/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2807 - accuracy: 0.9012 - val_loss: 0.3324 - val_accuracy: 0.8838
# Epoch 8/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2589 - accuracy: 0.9074 - val_loss: 0.3332 - val_accuracy: 0.8806
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2542 - accuracy: 0.9100 - val_loss: 0.3246 - val_accuracy: 0.8846
# Epoch 10/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2431 - accuracy: 0.9134 - val_loss: 0.3244 - val_accuracy: 0.8868
# 344/344 [==============================] - 1s 2ms/step - loss: 0.3205 - accuracy: 0.8877
# Epoch 1/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.7180 - accuracy: 0.7540 - val_loss: 0.4197 - val_accuracy: 0.8590
# Epoch 2/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3981 - accuracy: 0.8586 - val_loss: 0.3841 - val_accuracy: 0.8656
# Epoch 3/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3442 - accuracy: 0.8777 - val_loss: 0.3623 - val_accuracy: 0.8742
# Epoch 4/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3280 - accuracy: 0.8834 - val_loss: 0.3543 - val_accuracy: 0.8760
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3006 - accuracy: 0.8931 - val_loss: 0.3452 - val_accuracy: 0.8758
# Epoch 6/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2906 - accuracy: 0.8965 - val_loss: 0.3429 - val_accuracy: 0.8798
# Epoch 7/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2760 - accuracy: 0.9050 - val_loss: 0.3335 - val_accuracy: 0.8826
# Epoch 8/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2573 - accuracy: 0.9094 - val_loss: 0.3289 - val_accuracy: 0.8828
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2518 - accuracy: 0.9119 - val_loss: 0.3297 - val_accuracy: 0.8826
# Epoch 10/10
# 1375/1375 [==============================] - 5s 3ms/step - loss: 0.2423 - accuracy: 0.9168 - val_loss: 0.3254 - val_accuracy: 0.8870
# 344/344 [==============================] - 1s 2ms/step - loss: 0.3332 - accuracy: 0.8812
# Epoch 1/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.6988 - accuracy: 0.7619 - val_loss: 0.4137 - val_accuracy: 0.8598
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3962 - accuracy: 0.8592 - val_loss: 0.3737 - val_accuracy: 0.8710
# Epoch 3/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3484 - accuracy: 0.8773 - val_loss: 0.3602 - val_accuracy: 0.8748
# Epoch 4/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3164 - accuracy: 0.8886 - val_loss: 0.3544 - val_accuracy: 0.8764
# Epoch 5/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2957 - accuracy: 0.8953 - val_loss: 0.3377 - val_accuracy: 0.8862
# Epoch 6/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2787 - accuracy: 0.9031 - val_loss: 0.3404 - val_accuracy: 0.8802
# Epoch 7/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2675 - accuracy: 0.9066 - val_loss: 0.3297 - val_accuracy: 0.8856
# Epoch 8/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2548 - accuracy: 0.9104 - val_loss: 0.3300 - val_accuracy: 0.8844
# Epoch 9/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2436 - accuracy: 0.9155 - val_loss: 0.3299 - val_accuracy: 0.8864
# Epoch 10/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2300 - accuracy: 0.9209 - val_loss: 0.3265 - val_accuracy: 0.8838
# 344/344 [==============================] - 1s 2ms/step - loss: 0.3238 - accuracy: 0.8853
# Epoch 1/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6984 - accuracy: 0.7611 - val_loss: 0.4197 - val_accuracy: 0.8558
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3937 - accuracy: 0.8601 - val_loss: 0.3781 - val_accuracy: 0.8680
# Epoch 3/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3413 - accuracy: 0.8797 - val_loss: 0.3559 - val_accuracy: 0.8786
# Epoch 4/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3106 - accuracy: 0.8919 - val_loss: 0.3545 - val_accuracy: 0.8782
# Epoch 5/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2927 - accuracy: 0.8951 - val_loss: 0.3389 - val_accuracy: 0.8838
# Epoch 6/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2747 - accuracy: 0.9008 - val_loss: 0.3442 - val_accuracy: 0.8784
# Epoch 7/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2637 - accuracy: 0.9059 - val_loss: 0.3385 - val_accuracy: 0.8822
# Epoch 8/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2492 - accuracy: 0.9126 - val_loss: 0.3329 - val_accuracy: 0.8878
# Epoch 9/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2435 - accuracy: 0.9143 - val_loss: 0.3335 - val_accuracy: 0.8850
# Epoch 10/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2263 - accuracy: 0.9220 - val_loss: 0.3309 - val_accuracy: 0.8842
# 344/344 [==============================] - 1s 2ms/step - loss: 0.3327 - accuracy: 0.8804
# Epoch 1/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.7057 - accuracy: 0.7559 - val_loss: 0.4262 - val_accuracy: 0.8534
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3972 - accuracy: 0.8573 - val_loss: 0.3867 - val_accuracy: 0.8684
# Epoch 3/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3409 - accuracy: 0.8796 - val_loss: 0.3667 - val_accuracy: 0.8726
# Epoch 4/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.3138 - accuracy: 0.8897 - val_loss: 0.3578 - val_accuracy: 0.8770
# Epoch 5/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2957 - accuracy: 0.8939 - val_loss: 0.3425 - val_accuracy: 0.8770
# Epoch 6/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2811 - accuracy: 0.8995 - val_loss: 0.3539 - val_accuracy: 0.8730
# Epoch 7/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2668 - accuracy: 0.9065 - val_loss: 0.3466 - val_accuracy: 0.8798
# Epoch 8/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2492 - accuracy: 0.9112 - val_loss: 0.3382 - val_accuracy: 0.8822
# Epoch 9/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2436 - accuracy: 0.9141 - val_loss: 0.3329 - val_accuracy: 0.8852
# Epoch 10/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2309 - accuracy: 0.9179 - val_loss: 0.3287 - val_accuracy: 0.8848
# 344/344 [==============================] - 1s 2ms/step - loss: 0.3165 - accuracy: 0.8877
# Epoch 1/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.6827 - accuracy: 0.7681 - val_loss: 0.4125 - val_accuracy: 0.8572
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3943 - accuracy: 0.8591 - val_loss: 0.3752 - val_accuracy: 0.8670
# Epoch 3/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3388 - accuracy: 0.8808 - val_loss: 0.3578 - val_accuracy: 0.8734
# Epoch 4/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3209 - accuracy: 0.8865 - val_loss: 0.3466 - val_accuracy: 0.8778
# Epoch 5/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2948 - accuracy: 0.8925 - val_loss: 0.3356 - val_accuracy: 0.8840
# Epoch 6/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2865 - accuracy: 0.8966 - val_loss: 0.3349 - val_accuracy: 0.8798
# Epoch 7/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2729 - accuracy: 0.9053 - val_loss: 0.3263 - val_accuracy: 0.8844
# Epoch 8/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2508 - accuracy: 0.9112 - val_loss: 0.3272 - val_accuracy: 0.8840
# Epoch 9/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2462 - accuracy: 0.9140 - val_loss: 0.3183 - val_accuracy: 0.8860
# Epoch 10/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2343 - accuracy: 0.9192 - val_loss: 0.3161 - val_accuracy: 0.8904
# 344/344 [==============================] - 1s 2ms/step - loss: 0.3154 - accuracy: 0.8879
# Epoch 1/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.7029 - accuracy: 0.7602 - val_loss: 0.4047 - val_accuracy: 0.8606
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3949 - accuracy: 0.8592 - val_loss: 0.3707 - val_accuracy: 0.8676
# Epoch 3/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3407 - accuracy: 0.8785 - val_loss: 0.3518 - val_accuracy: 0.8746
# Epoch 4/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3242 - accuracy: 0.8846 - val_loss: 0.3461 - val_accuracy: 0.8768
# Epoch 5/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2954 - accuracy: 0.8948 - val_loss: 0.3343 - val_accuracy: 0.8788
# Epoch 6/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2869 - accuracy: 0.8966 - val_loss: 0.3366 - val_accuracy: 0.8786
# Epoch 7/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2704 - accuracy: 0.9048 - val_loss: 0.3270 - val_accuracy: 0.8800
# Epoch 8/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2513 - accuracy: 0.9115 - val_loss: 0.3188 - val_accuracy: 0.8850
# Epoch 9/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2450 - accuracy: 0.9148 - val_loss: 0.3205 - val_accuracy: 0.8872
# Epoch 10/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2357 - accuracy: 0.9185 - val_loss: 0.3130 - val_accuracy: 0.8900
# 344/344 [==============================] - 1s 2ms/step - loss: 0.3245 - accuracy: 0.8864
# Epoch 1/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.5962 - accuracy: 0.7932 - val_loss: 0.3998 - val_accuracy: 0.8624
# Epoch 2/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.3627 - accuracy: 0.8650 - val_loss: 0.3942 - val_accuracy: 0.8684
# Epoch 3/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.3167 - accuracy: 0.8849 - val_loss: 0.3778 - val_accuracy: 0.8764
# Epoch 4/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.2837 - accuracy: 0.8958 - val_loss: 0.3944 - val_accuracy: 0.8726
# Epoch 5/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2643 - accuracy: 0.9030 - val_loss: 0.3806 - val_accuracy: 0.8810
# Epoch 6/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.2435 - accuracy: 0.9101 - val_loss: 0.3968 - val_accuracy: 0.8756
# Epoch 7/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.2344 - accuracy: 0.9128 - val_loss: 0.3919 - val_accuracy: 0.8796
# Epoch 8/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.2146 - accuracy: 0.9202 - val_loss: 0.4073 - val_accuracy: 0.8810
# Epoch 9/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.2071 - accuracy: 0.9236 - val_loss: 0.3985 - val_accuracy: 0.8848
# Epoch 10/10
# 1375/1375 [==============================] - 2s 2ms/step - loss: 0.1954 - accuracy: 0.9285 - val_loss: 0.4227 - val_accuracy: 0.8822
# 344/344 [==============================] - 0s 1ms/step - loss: 0.4144 - accuracy: 0.8689
# Epoch 1/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.5965 - accuracy: 0.7916 - val_loss: 0.4104 - val_accuracy: 0.8562
# Epoch 2/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.3646 - accuracy: 0.8646 - val_loss: 0.3668 - val_accuracy: 0.8662
# Epoch 3/10
# 1375/1375 [==============================] - 3s 2ms/step - loss: 0.3131 - accuracy: 0.8846 - val_loss: 0.3598 - val_accuracy: 0.8752
# Epoch 4/10
# ...
# Epoch 10/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.1600 - accuracy: 0.9407 - val_loss: 0.4182 - val_accuracy: 0.8800
# 344/344 [==============================] - 1s 2ms/step - loss: 0.4264 - accuracy: 0.8781
# Epoch 1/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.6022 - accuracy: 0.7956 - val_loss: 0.4198 - val_accuracy: 0.8606
# Epoch 2/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3617 - accuracy: 0.8668 - val_loss: 0.3978 - val_accuracy: 0.8686
# Epoch 3/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3034 - accuracy: 0.8909 - val_loss: 0.4094 - val_accuracy: 0.8794
# Epoch 4/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2703 - accuracy: 0.9029 - val_loss: 0.3733 - val_accuracy: 0.8832
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2451 - accuracy: 0.9099 - val_loss: 0.3803 - val_accuracy: 0.8836
# Epoch 6/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2208 - accuracy: 0.9203 - val_loss: 0.3756 - val_accuracy: 0.8846
# Epoch 7/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2064 - accuracy: 0.9242 - val_loss: 0.3954 - val_accuracy: 0.8844
# Epoch 8/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.1819 - accuracy: 0.9321 - val_loss: 0.4134 - val_accuracy: 0.8802
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.1810 - accuracy: 0.9335 - val_loss: 0.4082 - val_accuracy: 0.8830
# Epoch 10/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.1602 - accuracy: 0.9418 - val_loss: 0.4139 - val_accuracy: 0.8754
# 344/344 [==============================] - 1s 2ms/step - loss: 0.4014 - accuracy: 0.8780
# Epoch 1/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.6097 - accuracy: 0.7896 - val_loss: 0.4413 - val_accuracy: 0.8496
# Epoch 2/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3685 - accuracy: 0.8671 - val_loss: 0.4185 - val_accuracy: 0.8654
# Epoch 3/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3076 - accuracy: 0.8882 - val_loss: 0.3897 - val_accuracy: 0.8728
# Epoch 4/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2680 - accuracy: 0.9043 - val_loss: 0.3721 - val_accuracy: 0.8816
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2450 - accuracy: 0.9103 - val_loss: 0.3786 - val_accuracy: 0.8828
# Epoch 6/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2307 - accuracy: 0.9141 - val_loss: 0.4027 - val_accuracy: 0.8746
# Epoch 7/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2023 - accuracy: 0.9254 - val_loss: 0.3904 - val_accuracy: 0.8820
# Epoch 8/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.1853 - accuracy: 0.9308 - val_loss: 0.4093 - val_accuracy: 0.8782
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.1760 - accuracy: 0.9361 - val_loss: 0.5448 - val_accuracy: 0.8852
# Epoch 10/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.1866 - accuracy: 0.9355 - val_loss: 0.5177 - val_accuracy: 0.8670
# 344/344 [==============================] - 1s 2ms/step - loss: 0.4758 - accuracy: 0.8678
# Epoch 1/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.6197 - accuracy: 0.7873 - val_loss: 0.3962 - val_accuracy: 0.8632
# Epoch 2/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3644 - accuracy: 0.8689 - val_loss: 0.4153 - val_accuracy: 0.8534
# Epoch 3/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2987 - accuracy: 0.8914 - val_loss: 0.4104 - val_accuracy: 0.8622
# Epoch 4/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2766 - accuracy: 0.8990 - val_loss: 0.3769 - val_accuracy: 0.8750
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2456 - accuracy: 0.9075 - val_loss: 0.3632 - val_accuracy: 0.8842
# Epoch 6/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2289 - accuracy: 0.9148 - val_loss: 0.3731 - val_accuracy: 0.8842
# Epoch 7/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2076 - accuracy: 0.9244 - val_loss: 0.3845 - val_accuracy: 0.8830
# Epoch 8/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.1905 - accuracy: 0.9284 - val_loss: 0.4437 - val_accuracy: 0.8806
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.1850 - accuracy: 0.9338 - val_loss: 0.3794 - val_accuracy: 0.8874
# Epoch 10/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.1666 - accuracy: 0.9400 - val_loss: 0.4221 - val_accuracy: 0.8770
# 344/344 [==============================] - 1s 2ms/step - loss: 0.4108 - accuracy: 0.8850
# Epoch 1/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.6083 - accuracy: 0.7910 - val_loss: 0.4099 - val_accuracy: 0.8616
# Epoch 2/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.3600 - accuracy: 0.8708 - val_loss: 0.4274 - val_accuracy: 0.8532
# Epoch 3/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2938 - accuracy: 0.8935 - val_loss: 0.3536 - val_accuracy: 0.8798
# Epoch 4/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2760 - accuracy: 0.8995 - val_loss: 0.3716 - val_accuracy: 0.8782
# Epoch 5/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2438 - accuracy: 0.9107 - val_loss: 0.3299 - val_accuracy: 0.8920
# Epoch 6/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2222 - accuracy: 0.9166 - val_loss: 0.3931 - val_accuracy: 0.8770
# Epoch 7/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.2047 - accuracy: 0.9241 - val_loss: 0.3566 - val_accuracy: 0.8846
# Epoch 8/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.1819 - accuracy: 0.9314 - val_loss: 0.3988 - val_accuracy: 0.8870
# Epoch 9/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.1803 - accuracy: 0.9362 - val_loss: 0.4377 - val_accuracy: 0.8690
# Epoch 10/10
# 1375/1375 [==============================] - 4s 3ms/step - loss: 0.1664 - accuracy: 0.9410 - val_loss: 0.4490 - val_accuracy: 0.8728
# 344/344 [==============================] - 1s 2ms/step - loss: 0.4698 - accuracy: 0.8720
# Epoch 1/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.6081 - accuracy: 0.7940 - val_loss: 0.4203 - val_accuracy: 0.8598
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3558 - accuracy: 0.8721 - val_loss: 0.4367 - val_accuracy: 0.8688
# Epoch 3/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.3004 - accuracy: 0.8916 - val_loss: 0.3760 - val_accuracy: 0.8810
# Epoch 4/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.2618 - accuracy: 0.9069 - val_loss: 0.3828 - val_accuracy: 0.8790
# Epoch 5/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.2386 - accuracy: 0.9128 - val_loss: 0.3771 - val_accuracy: 0.8866
# Epoch 6/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.2170 - accuracy: 0.9214 - val_loss: 0.3935 - val_accuracy: 0.8818
# Epoch 7/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2009 - accuracy: 0.9261 - val_loss: 0.3923 - val_accuracy: 0.8872
# Epoch 8/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.1865 - accuracy: 0.9310 - val_loss: 0.4057 - val_accuracy: 0.8846
# Epoch 9/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.1658 - accuracy: 0.9416 - val_loss: 0.4042 - val_accuracy: 0.8874
# Epoch 10/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.1516 - accuracy: 0.9459 - val_loss: 0.4553 - val_accuracy: 0.8774
# 344/344 [==============================] - 1s 2ms/step - loss: 0.4462 - accuracy: 0.8737
# Epoch 1/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.6171 - accuracy: 0.7921 - val_loss: 0.4561 - val_accuracy: 0.8514
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3592 - accuracy: 0.8709 - val_loss: 0.4026 - val_accuracy: 0.8674
# Epoch 3/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3017 - accuracy: 0.8907 - val_loss: 0.3635 - val_accuracy: 0.8802
# Epoch 4/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2616 - accuracy: 0.9043 - val_loss: 0.3617 - val_accuracy: 0.8850
# Epoch 5/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2378 - accuracy: 0.9138 - val_loss: 0.3745 - val_accuracy: 0.8886
# Epoch 6/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2154 - accuracy: 0.9213 - val_loss: 0.3597 - val_accuracy: 0.8840
# Epoch 7/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.1927 - accuracy: 0.9292 - val_loss: 0.4079 - val_accuracy: 0.8804
# Epoch 8/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.1773 - accuracy: 0.9366 - val_loss: 0.4281 - val_accuracy: 0.8780
# Epoch 9/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.1777 - accuracy: 0.9375 - val_loss: 0.4198 - val_accuracy: 0.8832
# Epoch 10/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.1486 - accuracy: 0.9440 - val_loss: 0.4676 - val_accuracy: 0.8714
# 344/344 [==============================] - 1s 2ms/step - loss: 0.4642 - accuracy: 0.8702
# Epoch 1/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.6201 - accuracy: 0.7915 - val_loss: 0.4575 - val_accuracy: 0.8448
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3631 - accuracy: 0.8685 - val_loss: 0.4361 - val_accuracy: 0.8690
# Epoch 3/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3040 - accuracy: 0.8901 - val_loss: 0.3957 - val_accuracy: 0.8726
# Epoch 4/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2644 - accuracy: 0.9067 - val_loss: 0.4057 - val_accuracy: 0.8744
# Epoch 5/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.2367 - accuracy: 0.9121 - val_loss: 0.3746 - val_accuracy: 0.8892
# Epoch 6/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.2208 - accuracy: 0.9200 - val_loss: 0.5818 - val_accuracy: 0.8690
# Epoch 7/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2086 - accuracy: 0.9283 - val_loss: 0.4385 - val_accuracy: 0.8818
# Epoch 8/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.1775 - accuracy: 0.9342 - val_loss: 0.4807 - val_accuracy: 0.8766
# Epoch 9/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.1650 - accuracy: 0.9391 - val_loss: 0.4424 - val_accuracy: 0.8844
# Epoch 10/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.1479 - accuracy: 0.9472 - val_loss: 0.5290 - val_accuracy: 0.8670
# 344/344 [==============================] - 1s 2ms/step - loss: 0.4673 - accuracy: 0.8739
# Epoch 1/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.6287 - accuracy: 0.7892 - val_loss: 0.3910 - val_accuracy: 0.8668
# Epoch 2/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.3641 - accuracy: 0.8688 - val_loss: 0.4260 - val_accuracy: 0.8638
# Epoch 3/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.3006 - accuracy: 0.8921 - val_loss: 0.4471 - val_accuracy: 0.8622
# Epoch 4/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.2733 - accuracy: 0.8991 - val_loss: 0.3631 - val_accuracy: 0.8744
# Epoch 5/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2382 - accuracy: 0.9121 - val_loss: 0.3517 - val_accuracy: 0.8910
# Epoch 6/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2167 - accuracy: 0.9188 - val_loss: 0.3957 - val_accuracy: 0.8840
# Epoch 7/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.1967 - accuracy: 0.9289 - val_loss: 0.3851 - val_accuracy: 0.8830
# Epoch 8/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.1781 - accuracy: 0.9339 - val_loss: 0.4131 - val_accuracy: 0.8788
# Epoch 9/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.1714 - accuracy: 0.9363 - val_loss: 0.3571 - val_accuracy: 0.8902
# Epoch 10/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.1515 - accuracy: 0.9452 - val_loss: 0.4275 - val_accuracy: 0.8784
# 344/344 [==============================] - 1s 2ms/step - loss: 0.4271 - accuracy: 0.8795
# Epoch 1/10
# 1375/1375 [==============================] - 6s 4ms/step - loss: 0.6256 - accuracy: 0.7887 - val_loss: 0.4012 - val_accuracy: 0.8636
# Epoch 2/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.3610 - accuracy: 0.8705 - val_loss: 0.4317 - val_accuracy: 0.8540
# Epoch 3/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2911 - accuracy: 0.8935 - val_loss: 0.3629 - val_accuracy: 0.8750
# Epoch 4/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2749 - accuracy: 0.8986 - val_loss: 0.3694 - val_accuracy: 0.8784
# Epoch 5/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2406 - accuracy: 0.9123 - val_loss: 0.3487 - val_accuracy: 0.8894
# Epoch 6/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.2164 - accuracy: 0.9202 - val_loss: 0.3723 - val_accuracy: 0.8806
# Epoch 7/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.1925 - accuracy: 0.9298 - val_loss: 0.3581 - val_accuracy: 0.8826
# Epoch 8/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.1705 - accuracy: 0.9373 - val_loss: 0.3630 - val_accuracy: 0.8860
# Epoch 9/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.1661 - accuracy: 0.9411 - val_loss: 0.3826 - val_accuracy: 0.8830
# Epoch 10/10
# 1375/1375 [==============================] - 5s 4ms/step - loss: 0.1526 - accuracy: 0.9458 - val_loss: 0.5921 - val_accuracy: 0.8602
# 344/344 [==============================] - 1s 2ms/step - loss: 0.6181 - accuracy: 0.8541
# Epoch 1/10
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.6561 - accuracy: 0.7771 - val_loss: 0.3986 - val_accuracy: 0.8614
# Epoch 2/10
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3799 - accuracy: 0.8625 - val_loss: 0.3587 - val_accuracy: 0.8712
# Epoch 3/10
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3379 - accuracy: 0.8818 - val_loss: 0.3596 - val_accuracy: 0.8734
# Epoch 4/10
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.3117 - accuracy: 0.8886 - val_loss: 0.3337 - val_accuracy: 0.8836
# Epoch 5/10
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2984 - accuracy: 0.8927 - val_loss: 0.3294 - val_accuracy: 0.8812
# Epoch 6/10
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2689 - accuracy: 0.9052 - val_loss: 0.3300 - val_accuracy: 0.8832
# Epoch 7/10
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2590 - accuracy: 0.9088 - val_loss: 0.3220 - val_accuracy: 0.8888
# Epoch 8/10
# 1719/1719 [==============================] - 7s 4ms/step - loss: 0.2425 - accuracy: 0.9134 - val_loss: 0.3285 - val_accuracy: 0.8820
# Epoch 9/10
# 1719/1719 [==============================] - 8s 5ms/step - loss: 0.2391 - accuracy: 0.9150 - val_loss: 0.3122 - val_accuracy: 0.8892
# Epoch 10/10
# 1719/1719 [==============================] - 8s 4ms/step - loss: 0.2217 - accuracy: 0.9228 - val_loss: 0.3129 - val_accuracy: 0.8910
# GridSearchCV(cv=None, error_score=nan,
#              estimator=<tensorflow.python.keras.wrappers.scikit_learn.KerasRegressor object at 0x7f27645eea20>,
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.0001, 0.01, 0.1],
#                          'n_units': [100, 300, 500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %% [markdown]
# Print the best hyper-parameters, and evaluate the best model on the test set.

# %%
print(grid_search.best_params_)

model = grid_search.best_estimator_.model
model.evaluate(X_test_scaled, y_test)
# Out:
# {'learning_rate': 0.01, 'n_units': 500}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3352 - accuracy: 0.8821
# [0.3352247476577759, 0.882099986076355]
